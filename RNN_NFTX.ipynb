# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
import tensorflow as tf

# %%
def split_data(df, choose):
  if choose == 1: # 7:2:1
    train_size = int(len(df) * 0.7)
    test_size = int(len(df) * 0.2)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  elif choose == 2: # 5:3:2
    train_size = int(len(df) * 0.5)
    test_size = int(len(df) * 0.3)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  elif choose == 3: # 6:2:2
    train_size = int(len(df) * 0.6)
    test_size = int(len(df) * 0.2)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  print("Train: ", train_size)
  print("Test: ", test_size)
  print("Val: ", val_size)

  return train_data, test_data, val_data

# %%
# load the dataset
df = pd.read_csv('/content/drive/MyDrive/Project/dataset/NFLX_Stock.csv',usecols=['Date', 'Price'], parse_dates=['Date'], index_col='Date')
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e4a44b0d290> in <cell line: 2>()
#       1 # load the dataset
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/Project/dataset/NFLX_Stock.csv',usecols=['Date', 'Price'], parse_dates=['Date'], index_col='Date')
#       3 df.info()
#
# NameError: name 'pd' is not defined

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

train_data, test_data, val_data = split_data(scaled_data, 1)
# Out:
# Train:  974
# Test:  278
# Val:  140

# %%
n_steps = 10
n_features = 1

# Tạo hàm input sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i + n_steps])
        y.append(data[i + n_steps])
    return np.array(X), np.array(y)

# Tạo input sequences cho training, validation, và testing
X_train, y_train = create_sequences(train_data, n_steps)
X_val, y_val = create_sequences(val_data, n_steps)
X_test, y_test = create_sequences(test_data, n_steps)

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# RNN

model = Sequential()
model.add(SimpleRNN(50, input_shape=(n_steps, n_features)))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')#, metrics=[MeanAbsolutePercentageError()])
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 31/31 [==============================] - 7s 25ms/step - loss: 0.0431 - val_loss: 0.0095
# Epoch 2/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 3/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 4/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0047
# Epoch 5/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0041
# Epoch 6/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 7/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 8/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 9/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 10/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 11/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 12/100
# 31/31 [==============================] - 0s 11ms/step - loss: 9.3748e-04 - val_loss: 0.0026
# Epoch 13/100
# 31/31 [==============================] - 0s 11ms/step - loss: 9.1277e-04 - val_loss: 0.0025
# Epoch 14/100
# 31/31 [==============================] - 0s 11ms/step - loss: 8.9139e-04 - val_loss: 0.0023
# Epoch 15/100
# 31/31 [==============================] - 0s 12ms/step - loss: 9.1252e-04 - val_loss: 0.0022
# Epoch 16/100
# 31/31 [==============================] - 0s 13ms/step - loss: 9.0780e-04 - val_loss: 0.0022
# Epoch 17/100
# 31/31 [==============================] - 0s 12ms/step - loss: 8.3840e-04 - val_loss: 0.0021
# Epoch 18/100
# 31/31 [==============================] - 0s 11ms/step - loss: 8.5923e-04 - val_loss: 0.0023
# Epoch 19/100
# 31/31 [==============================] - 0s 12ms/step - loss: 7.7778e-04 - val_loss: 0.0022
# Epoch 20/100
# 31/31 [==============================] - 0s 12ms/step - loss: 7.6363e-04 - val_loss: 0.0019
# Epoch 21/100
# 31/31 [==============================] - 0s 11ms/step - loss: 7.1980e-04 - val_loss: 0.0018
# Epoch 22/100
# 31/31 [==============================] - 0s 12ms/step - loss: 7.1238e-04 - val_loss: 0.0019
# Epoch 23/100
# 31/31 [==============================] - 0s 11ms/step - loss: 7.2954e-04 - val_loss: 0.0022
# Epoch 24/100
# 31/31 [==============================] - 0s 11ms/step - loss: 7.7695e-04 - val_loss: 0.0017
# Epoch 25/100
# 31/31 [==============================] - 0s 11ms/step - loss: 6.9887e-04 - val_loss: 0.0017
# Epoch 26/100
# 31/31 [==============================] - 0s 10ms/step - loss: 6.8530e-04 - val_loss: 0.0017
# Epoch 27/100
# 31/31 [==============================] - 0s 10ms/step - loss: 6.4002e-04 - val_loss: 0.0016
# Epoch 28/100
# 31/31 [==============================] - 0s 12ms/step - loss: 6.2792e-04 - val_loss: 0.0017
# Epoch 29/100
# 31/31 [==============================] - 0s 15ms/step - loss: 6.3527e-04 - val_loss: 0.0017
# Epoch 30/100
# 31/31 [==============================] - 1s 19ms/step - loss: 6.1864e-04 - val_loss: 0.0019
# Epoch 31/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.5659e-04 - val_loss: 0.0015
# Epoch 32/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.1824e-04 - val_loss: 0.0014
# Epoch 33/100
# 31/31 [==============================] - 1s 19ms/step - loss: 5.7017e-04 - val_loss: 0.0014
# Epoch 34/100
# 31/31 [==============================] - 1s 19ms/step - loss: 5.6879e-04 - val_loss: 0.0015
# Epoch 35/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.0533e-04 - val_loss: 0.0015
# Epoch 36/100
# 31/31 [==============================] - 0s 11ms/step - loss: 6.0004e-04 - val_loss: 0.0013
# Epoch 37/100
# 31/31 [==============================] - 0s 13ms/step - loss: 5.5695e-04 - val_loss: 0.0014
# Epoch 38/100
# 31/31 [==============================] - 0s 12ms/step - loss: 5.4601e-04 - val_loss: 0.0013
# Epoch 39/100
# 31/31 [==============================] - 0s 11ms/step - loss: 6.5795e-04 - val_loss: 0.0014
# Epoch 40/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.4685e-04 - val_loss: 0.0013
# Epoch 41/100
# 31/31 [==============================] - 0s 10ms/step - loss: 5.5036e-04 - val_loss: 0.0014
# Epoch 42/100
# 31/31 [==============================] - 0s 12ms/step - loss: 5.3507e-04 - val_loss: 0.0012
# Epoch 43/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.1695e-04 - val_loss: 0.0012
# Epoch 44/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.9223e-04 - val_loss: 0.0013
# Epoch 45/100
# 31/31 [==============================] - 0s 13ms/step - loss: 5.0951e-04 - val_loss: 0.0014
# Epoch 46/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.7927e-04 - val_loss: 0.0013
# Epoch 47/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.3659e-04 - val_loss: 0.0012
# Epoch 48/100
# 31/31 [==============================] - 0s 13ms/step - loss: 5.1987e-04 - val_loss: 0.0017
# Epoch 49/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.4480e-04 - val_loss: 0.0016
# Epoch 50/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.2254e-04 - val_loss: 0.0014
# Epoch 51/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.9455e-04 - val_loss: 0.0011
# Epoch 52/100
# 31/31 [==============================] - 0s 12ms/step - loss: 7.2122e-04 - val_loss: 0.0013
# Epoch 53/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.6839e-04 - val_loss: 0.0011
# Epoch 54/100
# 31/31 [==============================] - 0s 12ms/step - loss: 4.4913e-04 - val_loss: 0.0011
# Epoch 55/100
# 31/31 [==============================] - 0s 10ms/step - loss: 4.8684e-04 - val_loss: 0.0011
# Epoch 56/100
# 31/31 [==============================] - 0s 12ms/step - loss: 4.4774e-04 - val_loss: 0.0011
# Epoch 57/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.6527e-04 - val_loss: 0.0011
# Epoch 58/100
# 31/31 [==============================] - 0s 10ms/step - loss: 4.5219e-04 - val_loss: 0.0010
# Epoch 59/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.6286e-04 - val_loss: 0.0013
# Epoch 60/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.4507e-04 - val_loss: 0.0010
# Epoch 61/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.2604e-04 - val_loss: 9.5401e-04
# Epoch 62/100
# 31/31 [==============================] - 0s 10ms/step - loss: 4.8032e-04 - val_loss: 0.0010
# Epoch 63/100
# 31/31 [==============================] - 0s 13ms/step - loss: 4.3434e-04 - val_loss: 9.4822e-04
# Epoch 64/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.8707e-04 - val_loss: 9.4586e-04
# Epoch 65/100
# 31/31 [==============================] - 1s 19ms/step - loss: 5.3188e-04 - val_loss: 9.3608e-04
# Epoch 66/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.8067e-04 - val_loss: 9.8733e-04
# Epoch 67/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.1282e-04 - val_loss: 0.0010
# Epoch 68/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.4265e-04 - val_loss: 9.4671e-04
# Epoch 69/100
# 31/31 [==============================] - 1s 18ms/step - loss: 4.4044e-04 - val_loss: 0.0011
# Epoch 70/100
# 31/31 [==============================] - 0s 14ms/step - loss: 4.6712e-04 - val_loss: 9.9009e-04
# Epoch 71/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.1365e-04 - val_loss: 9.9880e-04
# Epoch 72/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.6618e-04 - val_loss: 9.1261e-04
# Epoch 73/100
# 31/31 [==============================] - 0s 13ms/step - loss: 4.5302e-04 - val_loss: 9.2194e-04
# Epoch 74/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.2099e-04 - val_loss: 9.7944e-04
# Epoch 75/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.0124e-04 - val_loss: 8.8416e-04
# Epoch 76/100
# 31/31 [==============================] - 0s 12ms/step - loss: 4.8869e-04 - val_loss: 0.0011
# Epoch 77/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.2439e-04 - val_loss: 0.0011
# Epoch 78/100
# 31/31 [==============================] - 0s 13ms/step - loss: 4.2474e-04 - val_loss: 9.6743e-04
# Epoch 79/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.3261e-04 - val_loss: 9.7359e-04
# Epoch 80/100
# 31/31 [==============================] - 0s 12ms/step - loss: 4.0780e-04 - val_loss: 8.5435e-04
# Epoch 81/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.2980e-04 - val_loss: 9.3747e-04
# Epoch 82/100
# 31/31 [==============================] - 0s 12ms/step - loss: 5.7613e-04 - val_loss: 0.0010
# Epoch 83/100
# 31/31 [==============================] - 1s 22ms/step - loss: 3.8815e-04 - val_loss: 8.6007e-04
# Epoch 84/100
# 31/31 [==============================] - 0s 12ms/step - loss: 3.9518e-04 - val_loss: 9.1697e-04
# Epoch 85/100
# 31/31 [==============================] - 0s 10ms/step - loss: 3.8072e-04 - val_loss: 9.9714e-04
# Epoch 86/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.0754e-04 - val_loss: 8.9571e-04
# Epoch 87/100
# 31/31 [==============================] - 0s 13ms/step - loss: 4.0795e-04 - val_loss: 9.8623e-04
# Epoch 88/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.1877e-04 - val_loss: 8.6710e-04
# Epoch 89/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.0857e-04 - val_loss: 8.7077e-04
# Epoch 90/100
# 31/31 [==============================] - 0s 10ms/step - loss: 4.0964e-04 - val_loss: 8.6214e-04
# Epoch 91/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.4727e-04 - val_loss: 9.6503e-04
# Epoch 92/100
# 31/31 [==============================] - 0s 12ms/step - loss: 3.8558e-04 - val_loss: 9.4355e-04
# Epoch 93/100
# 31/31 [==============================] - 0s 11ms/step - loss: 3.8257e-04 - val_loss: 9.0490e-04
# Epoch 94/100
# 31/31 [==============================] - 0s 12ms/step - loss: 3.9668e-04 - val_loss: 8.5906e-04
# Epoch 95/100
# 31/31 [==============================] - 1s 19ms/step - loss: 3.7942e-04 - val_loss: 0.0010
# Epoch 96/100
# 31/31 [==============================] - 1s 19ms/step - loss: 3.9464e-04 - val_loss: 9.0355e-04
# Epoch 97/100
# 31/31 [==============================] - 1s 19ms/step - loss: 3.9088e-04 - val_loss: 0.0010
# Epoch 98/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.0592e-04 - val_loss: 9.8956e-04
# Epoch 99/100
# 31/31 [==============================] - 1s 19ms/step - loss: 3.9664e-04 - val_loss: 0.0010
# Epoch 100/100
# 31/31 [==============================] - 1s 19ms/step - loss: 4.1533e-04 - val_loss: 7.9940e-04

# %%
# evaluate trên tập test
loss_test = model.evaluate(X_test, y_test, verbose=0)
print("loss_test: ", loss_test)

# evaluate trên tập val
loss_val = model.evaluate(X_val, y_val, verbose=0)
print("loss_val: ", loss_val)
# Out:
# loss_test:  0.0007993965991772711
# loss_val:  0.00033161306055262685

# %%
def mae_rmse_mape(true, predict):
  mae = mean_absolute_error(true, predict)
  rmse = np.sqrt(mean_squared_error(true, predict))
  mape = mean_absolute_percentage_error(true, predict)

  return mae, rmse, mape

# %%
y_pred_test = model.predict(X_test, verbose=0)
y_pred_val = model.predict(X_val, verbose=0)

# %%
y_pred_test = scaler.inverse_transform(y_pred_test)
y_pred_val = scaler.inverse_transform(y_pred_val)

y_test = scaler.inverse_transform(y_test)
y_val = scaler.inverse_transform(y_val)
y_train = scaler.inverse_transform(y_train)

# %%
mae_test, rmse_test, mape_test = mae_rmse_mape(y_test, y_pred_test)
mae_val, rmse_val, mape_val = mae_rmse_mape(y_val, y_pred_val)

print('MAE of Test: ', mae_test)
print('RMSE of Test: ', rmse_test)
print('MAPE of Test: ', mape_test)
print('------------------------')
print('MAE of Validation: ', mae_val)
print('RMSE of Validation: ', rmse_val)
print('MAPE of Validation: ', mape_val)
# Out:
# MAE of Test:  9.077191526498368
# RMSE of Test:  14.852685144566028
# MAPE of Test:  0.029592291100067277
# ------------------------
# MAE of Validation:  7.039043795072117
# RMSE of Validation:  9.566206370195735
# MAPE of Validation:  0.020787169469295014

# %%
mae_rmse_mape(y_test, y_pred_test)
# Out:
# (9.077191526498368, 14.852685144566028, 0.029592291100067277)

# %%
mae_rmse_mape(y_val, y_pred_val)
# Out:
# (7.039043795072117, 9.566206370195735, 0.020787169469295014)

# %%
number_days = 30

last_sequence = X_val[-1:]

predicted_values = []

for _ in range(number_days):
    next_value = model.predict(last_sequence)
    predicted_values.append(next_value[0, 0])
    last_sequence = np.append(last_sequence[:, 1:, :], [next_value], axis=1)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
predicted_values = scaler.inverse_transform(np.array(predicted_values).reshape(-1, 1))
#predicted_values = np.array(predicted_values).reshape(-1, 1)
predicted_values
# Out:
# array([[226280.67],
#        [225105.1 ],
#        [222924.11],
#        [221341.67],
#        [218511.8 ],
#        [216373.36],
#        [214653.17],
#        [212957.58],
#        [211733.27],
#        [210593.97],
#        [209553.16],
#        [208439.2 ],
#        [207413.95],
#        [206305.6 ],
#        [205152.7 ],
#        [203976.02],
#        [202782.53],
#        [201581.94],
#        [200385.62],
#        [199210.16],
#        [198044.67],
#        [196900.5 ],
#        [195773.23],
#        [194662.03],
#        [193563.36],
#        [192477.58],
#        [191402.94],
#        [190338.58],
#        [189285.31],
#        [188242.9 ]], dtype=float32)

# %%
plt.figure(figsize=(12,6))

plt.plot(range(len(y_train)), y_train, label='Train')

plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label='Test')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred_test, label='Test Prediction')

plt.plot(range(len(y_train) + len(y_test), len(y_train) + len(y_test) + len(y_val)), y_val, label='Validation')
plt.plot(range(len(y_train) + len(y_test), len(y_train) + len(y_test) + len(y_val)), y_pred_val, label='Validation Prediction')

plt.plot(range(len(y_train) + len(y_test) + len(y_val), len(y_train) + len(y_test) + len(y_val) + number_days), predicted_values, label='30days_Next')

plt.legend()
plt.show()
