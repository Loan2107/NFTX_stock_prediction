# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import tensorflow as tf

# %%
def split_data(df, choose):
  if choose == 1: # 7:2:1
    train_size = int(len(df) * 0.7)
    test_size = int(len(df) * 0.2)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  elif choose == 2: # 5:3:2
    train_size = int(len(df) * 0.5)
    test_size = int(len(df) * 0.3)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  elif choose == 3: # 6:2:2
    train_size = int(len(df) * 0.6)
    test_size = int(len(df) * 0.2)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  print("Train: ", train_size)
  print("Test: ", test_size)
  print("Val: ", val_size)

  return train_data, test_data, val_data

# %%
# load the dataset
df = pd.read_csv('/content/drive/MyDrive/Project/dataset/NFLX_Stock.csv',usecols=['Date', 'Price'], parse_dates=['Date'], index_col='Date')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1392 entries, 2017-12-01 to 2023-06-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1392 non-null   float64
# dtypes: float64(1)
# memory usage: 21.8 KB

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

train_data, test_data, val_data = split_data(scaled_data, 1)
# Out:
# Train:  974
# Test:  278
# Val:  140

# %%
# define the number of time steps and features
n_steps = 10
n_features = 1

# Tạo hàm input sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i + n_steps])
        y.append(data[i + n_steps])
    return np.array(X), np.array(y)

# Tạo input sequences cho training, validation, và testing
X_train, y_train = create_sequences(train_data, n_steps)
X_val, y_val = create_sequences(val_data, n_steps)
X_test, y_test = create_sequences(test_data, n_steps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0ac65a4fdb52> in <cell line: 18>()
#      16 X_test, y_test = create_sequences(test_data, n_steps)
#      17
# ---> 18 x_train
#
# NameError: name 'x_train' is not defined

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

X_train
# Out:
# array([[[0.03892865],
#         [0.03363664],
#         [0.03396025],
#         ...,
#         [0.03685373],
#         [0.0409084 ],
#         [0.04414452]],
#
#        [[0.03363664],
#         [0.03396025],
#         [0.03603518],
#         ...,
#         [0.0409084 ],
#         [0.04414452],
#         [0.04521054]],
#
#        [[0.03396025],
#         [0.03603518],
#         [0.03584482],
#         ...,
#         [0.04414452],
#         [0.04521054],
#         [0.04578162]],
#
#        ...,
#
#        [[0.7947156 ],
#         [0.82366938],
#         [0.84514201],
#         ...,
#         [0.88608848],
#         [0.8876304 ],
#         [0.87693216]],
#
#        [[0.82366938],
#         [0.84514201],
#         [0.85049113],
#         ...,
#         [0.8876304 ],
#         [0.87693216],
#         [0.87293459]],
#
#        [[0.84514201],
#         [0.85049113],
#         [0.83183583],
#         ...,
#         [0.87693216],
#         [0.87293459],
#         [0.88210995]]])

# %%
model = Sequential()
model.add(tf.keras.layers.LSTM(50,return_sequences=True, input_shape=(n_steps, n_features)))
model.add(tf.keras.layers.LSTM(50))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 10, 50)            10400
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')#, metrics=[MeanAbsolutePercentageError()])
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 31/31 [==============================] - 5s 31ms/step - loss: 0.0353 - val_loss: 0.0090
# Epoch 2/100
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 3/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 4/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 5/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 6/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 7/100
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 8/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 9/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 10/100
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 11/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 12/100
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0038
# Epoch 13/100
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 14/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 15/100
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 16/100
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 17/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 18/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0039
# Epoch 19/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 20/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 21/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 22/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 23/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 24/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 25/100
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 26/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 27/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 28/100
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 0.0035
# Epoch 29/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 30/100
# 31/31 [==============================] - 0s 7ms/step - loss: 9.3901e-04 - val_loss: 0.0035
# Epoch 31/100
# 31/31 [==============================] - 0s 7ms/step - loss: 9.4298e-04 - val_loss: 0.0025
# Epoch 32/100
# 31/31 [==============================] - 0s 7ms/step - loss: 9.7767e-04 - val_loss: 0.0036
# Epoch 33/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 34/100
# 31/31 [==============================] - 0s 7ms/step - loss: 9.2123e-04 - val_loss: 0.0032
# Epoch 35/100
# 31/31 [==============================] - 0s 8ms/step - loss: 8.9018e-04 - val_loss: 0.0029
# Epoch 36/100
# 31/31 [==============================] - 0s 7ms/step - loss: 8.1170e-04 - val_loss: 0.0028
# Epoch 37/100
# 31/31 [==============================] - 0s 7ms/step - loss: 8.5798e-04 - val_loss: 0.0022
# Epoch 38/100
# 31/31 [==============================] - 0s 7ms/step - loss: 7.9815e-04 - val_loss: 0.0021
# Epoch 39/100
# 31/31 [==============================] - 0s 7ms/step - loss: 8.9833e-04 - val_loss: 0.0019
# Epoch 40/100
# 31/31 [==============================] - 0s 13ms/step - loss: 8.2440e-04 - val_loss: 0.0019
# Epoch 41/100
# 31/31 [==============================] - 0s 13ms/step - loss: 7.6514e-04 - val_loss: 0.0020
# Epoch 42/100
# 31/31 [==============================] - 0s 8ms/step - loss: 7.3584e-04 - val_loss: 0.0020
# Epoch 43/100
# 31/31 [==============================] - 0s 9ms/step - loss: 7.5415e-04 - val_loss: 0.0019
# Epoch 44/100
# 31/31 [==============================] - 0s 15ms/step - loss: 8.0913e-04 - val_loss: 0.0026
# Epoch 45/100
# 31/31 [==============================] - 0s 10ms/step - loss: 7.8249e-04 - val_loss: 0.0019
# Epoch 46/100
# 31/31 [==============================] - 0s 8ms/step - loss: 6.8656e-04 - val_loss: 0.0021
# Epoch 47/100
# 31/31 [==============================] - 0s 14ms/step - loss: 7.5228e-04 - val_loss: 0.0022
# Epoch 48/100
# 31/31 [==============================] - 0s 11ms/step - loss: 7.3900e-04 - val_loss: 0.0022
# Epoch 49/100
# 31/31 [==============================] - 0s 7ms/step - loss: 6.8085e-04 - val_loss: 0.0017
# Epoch 50/100
# 31/31 [==============================] - 0s 8ms/step - loss: 7.4654e-04 - val_loss: 0.0018
# Epoch 51/100
# 31/31 [==============================] - 0s 9ms/step - loss: 6.9337e-04 - val_loss: 0.0017
# Epoch 52/100
# 31/31 [==============================] - 0s 7ms/step - loss: 7.3715e-04 - val_loss: 0.0017
# Epoch 53/100
# 31/31 [==============================] - 0s 8ms/step - loss: 6.3664e-04 - val_loss: 0.0015
# Epoch 54/100
# 31/31 [==============================] - 0s 8ms/step - loss: 6.3564e-04 - val_loss: 0.0016
# Epoch 55/100
# 31/31 [==============================] - 0s 7ms/step - loss: 6.4610e-04 - val_loss: 0.0016
# Epoch 56/100
# 31/31 [==============================] - 0s 9ms/step - loss: 6.0683e-04 - val_loss: 0.0015
# Epoch 57/100
# 31/31 [==============================] - 0s 9ms/step - loss: 5.9896e-04 - val_loss: 0.0016
# Epoch 58/100
# 31/31 [==============================] - 0s 8ms/step - loss: 6.2873e-04 - val_loss: 0.0019
# Epoch 59/100
# 31/31 [==============================] - 0s 8ms/step - loss: 6.2795e-04 - val_loss: 0.0015
# Epoch 60/100
# 31/31 [==============================] - 0s 9ms/step - loss: 6.2350e-04 - val_loss: 0.0015
# Epoch 61/100
# 31/31 [==============================] - 0s 7ms/step - loss: 5.8304e-04 - val_loss: 0.0014
# Epoch 62/100
# 31/31 [==============================] - 0s 8ms/step - loss: 5.5679e-04 - val_loss: 0.0014
# Epoch 63/100
# 31/31 [==============================] - 0s 7ms/step - loss: 5.4779e-04 - val_loss: 0.0017
# Epoch 64/100
# 31/31 [==============================] - 0s 7ms/step - loss: 5.4877e-04 - val_loss: 0.0013
# Epoch 65/100
# 31/31 [==============================] - 0s 10ms/step - loss: 5.4475e-04 - val_loss: 0.0017
# Epoch 66/100
# 31/31 [==============================] - 0s 9ms/step - loss: 5.9695e-04 - val_loss: 0.0013
# Epoch 67/100
# 31/31 [==============================] - 0s 10ms/step - loss: 5.1810e-04 - val_loss: 0.0012
# Epoch 68/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.1582e-04 - val_loss: 0.0015
# Epoch 69/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.8537e-04 - val_loss: 0.0012
# Epoch 70/100
# 31/31 [==============================] - 0s 12ms/step - loss: 5.2612e-04 - val_loss: 0.0013
# Epoch 71/100
# 31/31 [==============================] - 0s 12ms/step - loss: 4.6565e-04 - val_loss: 0.0012
# Epoch 72/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.0445e-04 - val_loss: 0.0012
# Epoch 73/100
# 31/31 [==============================] - 0s 11ms/step - loss: 5.1444e-04 - val_loss: 0.0015
# Epoch 74/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.7594e-04 - val_loss: 0.0012
# Epoch 75/100
# 31/31 [==============================] - 0s 11ms/step - loss: 4.5930e-04 - val_loss: 0.0013
# Epoch 76/100
# 31/31 [==============================] - 0s 9ms/step - loss: 5.2249e-04 - val_loss: 0.0012
# Epoch 77/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.5538e-04 - val_loss: 0.0011
# Epoch 78/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.4511e-04 - val_loss: 0.0011
# Epoch 79/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.5659e-04 - val_loss: 0.0013
# Epoch 80/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.3943e-04 - val_loss: 0.0013
# Epoch 81/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.6532e-04 - val_loss: 9.6914e-04
# Epoch 82/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.4486e-04 - val_loss: 0.0010
# Epoch 83/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.2874e-04 - val_loss: 0.0012
# Epoch 84/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.4014e-04 - val_loss: 9.5154e-04
# Epoch 85/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.5119e-04 - val_loss: 0.0010
# Epoch 86/100
# 31/31 [==============================] - 0s 9ms/step - loss: 4.3348e-04 - val_loss: 9.3690e-04
# Epoch 87/100
# 31/31 [==============================] - 0s 9ms/step - loss: 4.3598e-04 - val_loss: 0.0013
# Epoch 88/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.3359e-04 - val_loss: 0.0010
# Epoch 89/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.7818e-04 - val_loss: 9.9126e-04
# Epoch 90/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.3203e-04 - val_loss: 0.0010
# Epoch 91/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.3157e-04 - val_loss: 9.1698e-04
# Epoch 92/100
# 31/31 [==============================] - 0s 9ms/step - loss: 4.0818e-04 - val_loss: 9.7226e-04
# Epoch 93/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.0974e-04 - val_loss: 9.4894e-04
# Epoch 94/100
# 31/31 [==============================] - 0s 7ms/step - loss: 4.5707e-04 - val_loss: 9.5819e-04
# Epoch 95/100
# 31/31 [==============================] - 0s 9ms/step - loss: 4.5140e-04 - val_loss: 9.0411e-04
# Epoch 96/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.2720e-04 - val_loss: 0.0014
# Epoch 97/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.9203e-04 - val_loss: 8.7319e-04
# Epoch 98/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.0531e-04 - val_loss: 8.9325e-04
# Epoch 99/100
# 31/31 [==============================] - 0s 9ms/step - loss: 4.2190e-04 - val_loss: 9.0368e-04
# Epoch 100/100
# 31/31 [==============================] - 0s 8ms/step - loss: 4.8115e-04 - val_loss: 9.2508e-04

# %%
# evaluate trên tập test
loss_test = model.evaluate(X_test, y_test, verbose=0)
print("loss_test: ", loss_test)

# evaluate trên tập val
loss_val = model.evaluate(X_val, y_val, verbose=0)
print("loss_val: ", loss_val)
# Out:
# loss_test:  0.0009250833536498249
# loss_val:  0.00030377728398889303

# %%
def mae_rmse_mape(true, predict):
  mae = mean_absolute_error(true, predict)
  rmse = np.sqrt(mean_squared_error(true, predict))
  mape = mean_absolute_percentage_error(true, predict)

  return mae, rmse, mape

# %%
y_pred_test = model.predict(X_test)
y_pred_val = model.predict(X_val)

# y_pred_test = y_pred_test.reshape(-1,1)
# y_pred_val = y_pred_val.reshape(-1,1)

# y_pred_test = scaler.inverse_transform(y_pred_test)
# y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 9/9 [==============================] - 1s 3ms/step
# 5/5 [==============================] - 0s 3ms/step

# %%
y_pred_test = scaler.inverse_transform(y_pred_test)
y_pred_val = scaler.inverse_transform(y_pred_val)

y_test = scaler.inverse_transform(y_test)
y_val = scaler.inverse_transform(y_val)
y_train = scaler.inverse_transform(y_train)

# %%
# y_pred_test = y_pred_test.reshape(y_test.shape[0], 1)
# y_pred_val = y_pred_val.reshape(y_val.shape[0], 1)

# %%
mae_test, rmse_test, mape_test = mae_rmse_mape(y_test, y_pred_test)
mae_val, rmse_val, mape_val = mae_rmse_mape(y_val, y_pred_val)

print('MAE of Test: ', mae_test)
print('RMSE of Test: ', rmse_test)
print('MAPE of Test: ', mape_test)
print('------------------------')
print('MAE of Validation: ', mae_val)
print('RMSE of Validation: ', rmse_val)
print('MAPE of Validation: ', mape_val)
# Out:
# MAE of Test:  10.291780381843225
# RMSE of Test:  15.977703407397314
# MAPE of Test:  0.03607328043701205
# ------------------------
# MAE of Validation:  6.992521334134615
# RMSE of Validation:  9.155913174058012
# MAPE of Validation:  0.02092271000930671

# %%
number_days = 30

last_sequence = X_val[-1:]

predicted_values = []

for _ in range(number_days):
    next_value = model.predict(last_sequence)
    predicted_values.append(next_value[0, 0])
    last_sequence = np.append(last_sequence[:, 1:, :], [next_value], axis=1)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
predicted_values = scaler.inverse_transform(np.array(predicted_values).reshape(-1, 1))
#predicted_values = np.array(predicted_values).reshape(-1, 1)
predicted_values
# Out:
# array([[433.63058],
#        [434.68796],
#        [434.1858 ],
#        [433.30783],
#        [432.45908],
#        [431.95947],
#        [431.8966 ],
#        [432.18317],
#        [432.69547],
#        [433.35608],
#        [433.98538],
#        [434.60504],
#        [435.16003],
#        [435.6551 ],
#        [436.1032 ],
#        [436.52295],
#        [436.93127],
#        [437.34006],
#        [437.7561 ],
#        [438.1815 ],
#        [438.615  ],
#        [439.0544 ],
#        [439.49686],
#        [439.94   ],
#        [440.38226],
#        [440.82294],
#        [441.2619 ],
#        [441.69934],
#        [442.13577],
#        [442.57153]], dtype=float32)

# %%
plt.figure(figsize=(12,6))

plt.plot(range(len(y_train)), y_train, label='Train')

plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label='Test')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred_test, label='Test Prediction')

plt.plot(range(len(y_train) + len(y_test), len(y_train) + len(y_test) + len(y_val)), y_val, label='Validation')
plt.plot(range(len(y_train) + len(y_test), len(y_train) + len(y_test) + len(y_val)), y_pred_val, label='Validation Prediction')

plt.plot(range(len(y_train) + len(y_test) + len(y_val), len(y_train) + len(y_test) + len(y_val) + number_days), predicted_values, label='30days_Next')

plt.legend()
plt.show()
